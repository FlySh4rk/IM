# %% [markdown]
# # Test the model
#
# Loads the saved model and test it with some data.

# %%
import numpy as np
import tensorflow as tf

model = tf.keras.models.load_model("model3")
model.summary()
# Out:
# 2024-01-04 18:37:29.822270: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2024-01-04 18:37:29.822295: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2024-01-04 18:37:29.822302: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2024-01-04 18:37:29.822333: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-01-04 18:37:29.822349: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 16)]                 0         []
#
#  cross_product_layer_4 (Cro  (None, 152)                  152       ['input_5[0][0]']
#  ssProductLayer)
#
#  repeat_vector_3 (RepeatVec  (None, 2, 152)               0         ['cross_product_layer_4[0][0]'
#  tor)                                                               ]
#
#  tf.__operators__.getitem_5  (None, 152)                  0         ['repeat_vector_3[0][0]']
#   (SlicingOpLambda)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 152)                  0         ['tf.__operators__.getitem_5[0
#                                                                     ][0]']
#
#  dense_3 (Dense)             (None, 64)                   9792      ['leaky_re_lu_2[0][0]']
#
#  tf.__operators__.getitem_6  (None, 152)                  0         ['repeat_vector_3[0][0]']
#   (SlicingOpLambda)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 64)                   0         ['dense_3[0][0]']
#
#  concatenate_2 (Concatenate  (None, 216)                  0         ['tf.__operators__.getitem_6[0
#  )                                                                  ][0]',
#                                                                      'leaky_re_lu_3[0][0]']
#
#  dense_4 (Dense)             (None, 4)                    868       ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 10812 (42.23 KB)
# Trainable params: 10812 (42.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import pandas as pd

input_dataset = pd.read_pickle("input_rot.pkl")

# %% [markdown]
# ## Now try to visualize things
#
# Let's try drawing *tooth*, *bone* and *axe*.

# %%
from utils import draw_samples


def apply(row: np.ndarray) -> np.ndarray:
    return model(row.reshape(1, -1)).numpy()


draw_samples(model=None, input_dataset=input_dataset, apply=apply)
# Out:
# 2024-01-04 18:37:37.530560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.

# %%
draw_samples(model=None, input_dataset=input_dataset, num_samples=5, apply=apply)

# %%
draw_samples(model=None, input_dataset=input_dataset, num_rows=3, num_samples=6, apply=apply)

# %%
from utils import draw_row
from matplotlib import pyplot as plt

draw_row(model=None,
         ax=plt.figure().add_axes((0., 0., 1., 1.)),
         row=np.array([0, 0, 4, 0, 4, 1, 0, 1,  # bone
                       0, 1, 1, 1, 1, 2, 0, 2]),
         apply=apply)
